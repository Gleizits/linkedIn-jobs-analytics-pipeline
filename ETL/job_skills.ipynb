# %% [markdown]
# # Download Python Libs

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib

# %% [markdown]
# # Import Libs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # ETL PROCESS

# %% [markdown]
# ## Extract

# %%
data = pd.read_csv('job_skills.csv', sep='\t', engine='python')
data
# Out:
#                                       job_link,job_skills
# 0       https://www.linkedin.com/jobs/view/housekeeper...
# 1       https://www.linkedin.com/jobs/view/assistant-g...
# 2       https://www.linkedin.com/jobs/view/school-base...
# 3       https://www.linkedin.com/jobs/view/electrical-...
# 4       https://www.linkedin.com/jobs/view/electrical-...
# ...                                                   ...
# 419807  https://www.linkedin.com/jobs/view/sr-distribu...
# 419808  https://www.linkedin.com/jobs/view/unit-manage...
# 419809  https://ca.linkedin.com/jobs/view/statistical-...
# 419810  https://www.linkedin.com/jobs/view/quality-man...
# 419811  https://www.linkedin.com/jobs/view/copy-of-nam...
#
# [419812 rows x 1 columns]
