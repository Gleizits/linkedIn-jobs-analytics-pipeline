# %% [markdown]
# # Download Python Libs

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install kaggle

# %% [markdown]
# # Import Libs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Download CSV

# %%
# !kaggle datasets download -d asaniczka/1-3m-linkedin-jobs-and-skills-dataset-2024 --unzip

# %% [markdown]
# # ETL PROCESS

# %% [markdown]
# ## Extract

# %%
data = pd.read_csv('linkedin_job_postings.csv')
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8500/2612082159.py in <cell line: 0>()
# ----> 1 data = pd.read_csv('/kaggle/input/1-3m-linkedin-jobs-and-skills-dataset-2024/linkedin_job_postings.csv')
#       2 data
#
# ...
